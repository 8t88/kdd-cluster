# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('KDDTest+.csv', header=None, names=col_names)

# %%
#pandas encode columns 'protocol_type', 'service', 'flag'

# %%
num_vars = 4#40
labels_array = data['index_label']
num_labels = labels_array.nunique()
#one-hot

fig = plt.figure(figsize=(10,40), tight_layout=True)
subp = 1
cols = data.columns
#for x in range(0,len(cols)-2):
for x in range(5,8):
    ax = fig.add_subplot(num_vars,1,subp)
    
    plt.scatter(data[cols[x]], data[cols[x+1]], c=labels_array)
    subp+=1
    ax.set_xlabel(cols[x])
    ax.set_ylabel(cols[x+1])
    #ax.set_title(x)
fig.show()
# Out:
# /home/train/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# /home/train/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
data['index_label'].nunique()
# Out:
# 22

# %%
np.array(data["dst_host_srv_diff_host_rate"])
# Out:
# array([0.  , 0.  , 0.02, ..., 0.  , 0.  , 0.  ])

# %%
np.array(y_num_label)
# Out:
# array([1, 1, 1, ..., 1, 1, 3])

# %%
type(y_num_label)
# Out:
# list

# %%
y_num_label = data['index_label']

plt.subplot(2,1,1)
plt.plot(data["dst_host_srv_diff_host_rate"], data["dst_host_serror_rate"], '.')
plt.legend()
plt.show()

# %%
col_names = ["duration",
"protocol_type",
"service",
"flag",
"src_bytes",
"dst_bytes",
"land",
"wrong_fragment",
"urgent",
"hot",
"num_failed_logins",
"logged_in",
"num_compromised",
"root_shell",
"su_attempted",
"num_root",
"num_file_creations",
"num_shells",
"num_access_files",
"num_outbound_cmds",
"is_host_login",
"is_guest_login",
"count",
"srv_count",
"serror_rate",
"srv_serror_rate",
"rerror_rate",
"srv_rerror_rate",
"same_srv_rate",
"diff_srv_rate",
"srv_diff_host_rate",
"dst_host_count",
"dst_host_srv_count",
"dst_host_same_srv_rate",
"dst_host_diff_srv_rate",
"dst_host_same_src_port_rate",
"dst_host_srv_diff_host_rate",
"dst_host_serror_rate",
"dst_host_srv_serror_rate",
"dst_host_rerror_rate",
"dst_host_srv_rerror_rate",
"label",
"index_label"]
